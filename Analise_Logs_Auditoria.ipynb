# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')

df_logs = pd.read_csv('/content/drive/MyDrive/PROJETOS_LOGS/labeled.csv', nrows=1000000)
df_logs.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#               ip                       time method  \
# 0    31.56.96.51  2019-01-22 00:26:16+00:00    GET
# 1    31.56.96.51  2019-01-22 00:26:16+00:00    GET
# 2    91.99.72.15  2019-01-22 00:26:17+00:00    GET
# 3  178.253.33.51  2019-01-22 00:26:19+00:00    GET
# 4    91.99.72.15  2019-01-22 00:26:19+00:00    GET
#
#                                                  url  protocol  status   size  \
# 0                  /image/60844/productModel/200x200  HTTP/1.1     200   5667
# 1                  /image/61474/productModel/200x200  HTTP/1.1     200   5379
# 2  /product/31893/62100/سشوار-خانگی-پرنسلی-مدل-PR...  HTTP/1.1     200  41483
# 3  /m/product/32574/62991/ماشین-اصلاح-صورت-پرنسلی...  HTTP/1.1     200  20406
# 4  /product/10075/13903/مایکروفر-رومیزی-سامسونگ-م...  HTTP/1.1     200  41725
#
#                                             referrer  \
# ...

# %%
contagem_ataques = df_logs['type'].value_counts()
print(contagem_ataques)
# Out:
# type
# benign      999822
# bot            141
# scanning        20
# rce             17
# Name: count, dtype: int64

# %% [markdown]
# **Análise de Risco e Filtragem: **
# Lógica aplicada para isolar o tráfego não-humano (bots e scanners) e tentativas de execução remota de código (RCE). O objetivo é garantir a investigação ágil das anomalias que receberam o statos 200 (OK), e passaram pelas camadas iniciais de defesa da infraestrutura.

# %%
df_auditoria = df_logs[df_logs['type'] != 'benign']
df_auditoria[['ip', 'time', 'type', 'status']].head(10)
# Out:
#                    ip                       time type  status
# 236    216.244.66.248  2019-01-22 00:27:28+00:00  bot     301
# 238    216.244.66.248  2019-01-22 00:27:30+00:00  bot     200
# 1305     74.6.168.162  2019-01-22 00:32:46+00:00  bot     301
# 1306     74.6.168.162  2019-01-22 00:32:48+00:00  bot     200
# 2798   213.174.147.83  2019-01-22 00:43:08+00:00  bot     301
# 2799   213.174.147.83  2019-01-22 00:43:08+00:00  bot     200
# 3809     95.216.2.253  2019-01-22 00:49:39+00:00  bot     200
# 4410  207.241.231.165  2019-01-22 00:55:10+00:00  bot     301
# 5225   46.225.135.218  2019-01-22 01:02:10+00:00  bot     200
# 7359   216.244.66.248  2019-01-22 01:13:22+00:00  bot     301

# %%
df_auditoria.to_csv('relatorio_auditoria_ameacas.csv', index=False)
print('Relatório de evidências gerado com sucesso!')
# Out:
# Relatório de evidências gerado com sucesso!
